saison_id/2021/plus/1',
    'https://www.transfermarkt.com/bahlinger-sc/kader/verein/1193/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/tsg-balingen/kader/verein/834/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/fk-pirmasens/kader/verein/726/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/tsv-schott-mainz/kader/verein/9695/saison_id/2021/plus/1'
    
]

List_of_Regionalliga_Nord_club_urls = [
    'https://www.transfermarkt.com/sv-werder-bremen-ii/kader/verein/87/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/hamburger-sv-ii/kader/verein/389/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/hannover-96-ii/kader/verein/1065/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/fc-st-pauli-ii/kader/verein/225/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/holstein-kiel-ii/kader/verein/1171/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/sc-weiche-flensburg-08/kader/verein/10284/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/vfb-lubeck/kader/verein/78/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/vfb-oldenburg/kader/verein/166/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/fc-teutonia-05-ottensen/kader/verein/14361/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/eintracht-norderstedt/kader/verein/117/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/sv-drochtersen-assel/kader/verein/10213/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/1-fc-phonix-lubeck/kader/verein/2773/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/sv-atlas-delmenhorst/kader/verein/29988/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/ssv-jeddeloh-ii/kader/verein/6776/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/bsv-schwarz-weiss-rehden/kader/verein/5560/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/luneburger-sk-hansa/kader/verein/18324/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/vfv-borussia-06-hildesheim/kader/verein/2540/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/altona-93/kader/verein/298/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/heider-sv/kader/verein/1297/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/fc-oberneuland/kader/verein/115/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/hsc-hannover/kader/verein/3925/saison_id/2021/plus/1'
]

List_of_Regionalliga_Northeast_club_urls = [
    'https://www.transfermarkt.com/hertha-bsc-ii/kader/verein/45/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/fc-energie-cottbus/kader/verein/25/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/fc-carl-zeiss-jena/kader/verein/113/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/bfc-dynamo/kader/verein/222/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/berliner-ak-07/kader/verein/584/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/chemnitzer-fc/kader/verein/21/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/vsg-altglienicke/kader/verein/17847/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/1-fc-lokomotive-leipzig/kader/verein/497/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/zfc-meuselwitz/kader/verein/2643/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/bsg-chemie-leipzig/kader/verein/9572/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/sv-babelsberg-03/kader/verein/90/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/germania-halberstadt/kader/verein/364/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/fsv-63-luckenwalde/kader/verein/5761/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/tennis-borussia-berlin/kader/verein/101/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/sv-lichtenberg-47/kader/verein/1333/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/vfb-auerbach/kader/verein/1400/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/fsv-optik-rathenow/kader/verein/562/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/fc-eilenburg/kader/verein/4825/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/fsv-union-furstenwalde/kader/verein/5300/saison_id/2021/plus/1',
    'https://www.transfermarkt.com/sv-tasmania-berlin/kader/verein/5608/saison_id/2021/plus/1'
    
]

# %%
List_of_club_urls = List_of_Regionalliga_West_club_urls + List_of_Regionalliga_Bayern_club_urls + List_of_Regionalliga_Südwest_club_urls + List_of_Regionalliga_Nord_club_urls + List_of_Regionalliga_Northeast_club_urls

# %% [markdown]
# #### Insuring all Club URLS are for year 2022

# %%
List_of_club_urls = [s.replace('2021', '2022') for s in List_of_club_urls]

# %% [markdown]
# #### Looping through the URLS and Scraping the needed Data in a Dataframe

# %%
data = pd.DataFrame(columns= ['Player','Team', 'Date of birth / Age', 'Height', 'Joined', 'Contract', 'Market value'])
for club in List_of_club_urls:
    ssl._create_default_https_context = ssl._create_unverified_context
    from urllib.request import Request, urlopen    
    url = f"{club}"    
    req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})    
    html = urlopen(req)

    scraped = pd.read_html(html)
    df = scraped[1]
    df = df[['Player', 'Date of birth / Age', 'Height', 'Joined', 'Contract', 'Market value']]
    df = df.dropna()
    two = df.Player.str.split(pat=' ',expand=True)
    two['first']= two.iloc[:, 0] + ' ' + two.iloc[:, 1]
    df['Player'] = two['first']
    df['Team'] = club.split('/')[-8].replace("-", " ")
    data = pd.concat([data, df], axis=0)
data
# Out:
#                Player                Team Date of birth / Age Height  \
# 0    Gavin Didzilatis        1 fc koln ii   Feb 28, 2002 (20)  1,88m
# 3     Tobias Trautner        1 fc koln ii    Mar 5, 1995 (27)  1,88m
# 6      Stephan Salger        1 fc koln ii   Jan 30, 1990 (32)  1,83m
# 9        Rijad Smajic        1 fc koln ii    May 2, 2004 (18)  1,90m
# 12  Teoman Akmestanli        1 fc koln ii   Jan 30, 2002 (20)  1,88m
# ..                ...                 ...                 ...    ...
# 69     Kubilay Yilmaz  sv tasmania berlin   Apr 11, 2002 (20)  1,82m
# 72       Serhat Polat  sv tasmania berlin   Feb 13, 2001 (21)      -
# 75         Nigel Bier  sv tasmania berlin   Mar 19, 1993 (29)  1,83m
# 78      Martin Oliver  sv tasmania berlin    Oct 9, 2000 (22)  1,78m
# 81   Dominik Böttcher  sv tasmania berlin   Feb 22, 1995 (27)  1,78m
#
#          Joined      Contract Market value
# 0   Jul 1, 2022  Jun 30, 2023         €50k
# 3   Mar 1, 2022  Jun 30, 2023         €10k
# ...

# %%
data.index = range(len(data.index))
data
# Out:
#                  Player                Team Date of birth / Age Height  \
# 0      Gavin Didzilatis        1 fc koln ii   Feb 28, 2002 (20)  1,88m
# 1       Tobias Trautner        1 fc koln ii    Mar 5, 1995 (27)  1,88m
# 2        Stephan Salger        1 fc koln ii   Jan 30, 1990 (32)  1,83m
# 3          Rijad Smajic        1 fc koln ii    May 2, 2004 (18)  1,90m
# 4     Teoman Akmestanli        1 fc koln ii   Jan 30, 2002 (20)  1,88m
# ...                 ...                 ...                 ...    ...
# 2591     Kubilay Yilmaz  sv tasmania berlin   Apr 11, 2002 (20)  1,82m
# 2592       Serhat Polat  sv tasmania berlin   Feb 13, 2001 (21)      -
# 2593         Nigel Bier  sv tasmania berlin   Mar 19, 1993 (29)  1,83m
# 2594      Martin Oliver  sv tasmania berlin    Oct 9, 2000 (22)  1,78m
# 2595   Dominik Böttcher  sv tasmania berlin   Feb 22, 1995 (27)  1,78m
#
#            Joined      Contract Market value
# 0     Jul 1, 2022  Jun 30, 2023         €50k
# ...

# %%
data.to_excel("TransferMarket for Germany's 4th tier players.xlsx", encoding='utf-8', index=False)
